# %%
import math

EMISSION_COST = 1.4  # f_c
FRICTION_FACTOR = 0.2  # k
ENGINE_SPEED = 33  # N
ENGINE_DISPLACEMENT = 5  # V
LAMBDA = 1 / (44 * 737)  # xi/(kappa*phi), xi = 1, kappa = 44, phi = 737
CURB_WEIGHT = 6350  # w
GAMMA = 1 / (1000 * 0.4 * 0.9)  # 1/(1000*n_tf*n)
BETTA = 0.5 * 0.7 * 1.2041 * 3.912  # 0.5*Cd*Rho*A
DRIVER_COST = 0.0022  # f_d (pounds/s)
ROLLING_RESISTANCE = 0.01  # C_r
GRAVITY = 9.81  # g
fixed_degree = 0.0107459922
ALPHA = GRAVITY * (math.sin(fixed_degree) + ROLLING_RESISTANCE * math.cos(fixed_degree))

# %%
class PRProblem:
    def __init__(self, n_customers, vehicle_curb, max_payload, min_speed, max_speed, dist, customers,
                 fleet_size=2):
        self.n_customers = n_customers
        self.vehicle_curb = vehicle_curb
        self.max_payload = max_payload
        self.min_speed = min_speed
        self.max_speed = max_speed
        self.dist = dist
        self.customers = customers
        self.fleet_size = fleet_size

    def __str__(self):
        return "n. customers: {}\n" \
               "vehicle curb: {}\n" \
               "max payload: {}\n" \
               "min speed: {} max speed: {}\n" \
               "distances: {}\n" \
               "customers: {}".format(self.n_customers,
                                      self.vehicle_curb,
                                      self.max_payload,
                                      self.min_speed, self.max_speed,
                                      self.dist,
                                      self.customers)

# %%
def read_instance(inst_name):
    with open("instances/{}.txt".format(inst_name)) as file:
        n_customers = int(file.readline())
        file.readline()
        curb_payload = file.readline().split()
        vehicle_curb = float(curb_payload[0])
        max_payload = float(curb_payload[1])
        file.readline()
        speeds = file.readline().split()
        min_speed = int(speeds[0])
        max_speed = int(speeds[1])
        file.readline()
        dist = {}
        for row in range(0, n_customers+2):
            line = file.readline()
            for col, value in enumerate(line.split()):
                dist[(int(row), int(col))] = float(value)

        file.readline()
        customers = []
        while len(customers) != n_customers+1:
            line = file.readline()
            info = line.split()
            if len(info) > 0:
                customers.append({"id": int(info[0]),
                                  "city_name": info[1],
                                  "demand": float(info[2]),
                                  "ready_time": float(info[3]),
                                  "due_time": float(info[4]),
                                  "service_time": float(info[5])})

    return PRProblem(n_customers, vehicle_curb, max_payload, min_speed, max_speed, dist, customers)

# %%
import copy
import time
import random
from random import randrange
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

SEPARATOR = -1


class PRP_Genetic:
    def __init__(self, prp: PRProblem):
        self.prp = prp

    def generate_chromosome(self):
        """
        Generate a random chromosome
        :return: chromosome
        """
        route = []
        for i in range(1, self.prp.n_customers + 1):
            customer = i
            speed = random.randint(self.prp.min_speed, self.prp.max_speed)
            route.append([customer, speed])
        random.shuffle(route)
        routes = self.split_route(route)

        chromosome = []
        for route in routes:
            speed_sep = random.randint(self.prp.min_speed, self.prp.max_speed)
            chromosome += route + [[SEPARATOR, speed_sep]]

        return chromosome

    def generate_initial_population(self, population_size):
        """
        Generate a population with ``population_size`` individuals
        :param population_size: number of individuals of the population being generated
        :return: new population
        """
        return [self.generate_chromosome() for _ in range(population_size)]

    def generate_next_population(self, current_population, crossover_rate, route_mutation_rate, speed_mutation_rate,
                                 selection_method, elitism_rate=0.0, maintain_diversity=False):
        """

        :param current_population: the current population
        :param n_chromosomes: the number of individuals selected from tournament
        :param k_tournament: the number of individuals involved in the tournament
        :param route_mutation_rate: route mutation rate, a real number in the interval [0,1]
        :param speed_mutation_rate:  speed mutation rate, a real number in the interval [0,1]
        :return: new population
        """
        n_parents = len(current_population)
        new_children = []

        n_elitism = round(elitism_rate*n_parents)
        best_chromosomes = sorted(current_population, key=self.fitness)[:n_elitism]
        new_children.extend(best_chromosomes)
        n_parents -= n_elitism
        n_parents = (n_parents if n_parents % 2 == 0 else n_parents - 1)

        parents = selection_method(current_population, n_parents)
        random.shuffle(parents)
        for i in range(0, n_parents, 2):
            parent1 = parents[i]
            parent2 = parents[i + 1]
            if maintain_diversity:
                is_new = False
                while not is_new:
                    child1, child2 = self.mate(parent1, parent2, crossover_rate, route_mutation_rate, speed_mutation_rate)
                    curr_pop = new_children + parents
                    if child1 not in curr_pop and child2 not in curr_pop:
                        is_new = True
            else:
                child1, child2 = self.mate(parent1, parent2, crossover_rate, route_mutation_rate, speed_mutation_rate)

            new_children.append(child1)
            new_children.append(child2)

        return new_children

    def mate(self, parent1, parent2, crossover_rate, route_mutation_rate, speed_mutation_rate):
        parent1 = copy.deepcopy(parent1)
        parent2 = copy.deepcopy(parent2)

        # remove separators, turning the VRP representation into TSP representation
        parent1 = [x for x in parent1 if x[0] != SEPARATOR]
        parent2 = [x for x in parent2 if x[0] != SEPARATOR]

        if random.random() < crossover_rate:
            child1, child2 = self.crossover(parent1, parent2)
        else:
            child1, child2 = parent1, parent2

        child1 = self.shift(child1, mutation_rate=route_mutation_rate, speed_mutation_rate=speed_mutation_rate)
        child2 = self.shift(child2, mutation_rate=route_mutation_rate, speed_mutation_rate=speed_mutation_rate)
        child1 = self.add_separator(child1)
        child2 = self.add_separator(child2)
        return child1, child2

    def sus(self, population, n, k):
        """
        Stochastic Universal Sampling.
        Reference: https://en.wikipedia.org/wiki/Stochastic_universal_sampling

        :param population: population: current population
        :param k: the number of individuals to selected
        :param n: the number of individuals to keep
        :return: a list of selected individuals
        """
        new_population = []
        n_rounds = round(n/k)
        for _ in range(n_rounds):
            fitness_scores = [1/self.fitness(chromosome) for chromosome in population]
            total_fitness = sum(fitness_scores)
            point_distance = total_fitness / k
            start_point = random.uniform(0, point_distance)
            points = [start_point + i * point_distance for i in range(k)]

            keep = []
            for p in points:
                i = -1
                cumulative_sum = 0
                while cumulative_sum < p:
                    i += 1
                    cumulative_sum += fitness_scores[i]

                keep.append(population[i])
            new_population.extend(keep)
        return new_population

    def tournament_selection(self, population, n, k=2):
        """
        Given a population, make k individuals fight against each other and the one with lowest fitness score wins.
        Repeat this process n times.

        :param population: current population
        :param n: the number of individuals selected from the tournament
        :param k: the number of  individuals involved in the tournament
        :return: a list with the winners
        """
        winners = []
        for _ in range(n):
            elements = random.sample(population, k)
            winners.append(min(elements, key=self.fitness))

        return winners

    def fitness(self, chromosome):
        """

        :param chromosome: a chromosome
        :return: its fitness score
        """
        objective = 0
        prev_customer = 0
        const1 = FRICTION_FACTOR * ENGINE_SPEED * ENGINE_DISPLACEMENT * LAMBDA
        const2 = CURB_WEIGHT * GAMMA * LAMBDA * ALPHA
        const3 = GAMMA * LAMBDA * ALPHA
        const4 = BETTA * GAMMA * LAMBDA

        cumulative_time = 0
        cumulative_payload = 0
        total_payloads = self.compute_total_payload(chromosome)
        route_index = 0
        for item in chromosome:
            current_customer = item[0]
            is_separator = current_customer == SEPARATOR
            if is_separator:
                current_customer = 0
            speed = item[1]
            dist = self.prp.dist[prev_customer, current_customer]
            objective += const1 * dist / speed
            objective += const2 * dist
            objective += const4 * dist * (speed ** 2)

            # Driver Cost
            prev_service_time = self.prp.customers[prev_customer]['service_time']
            displacement_time = self.prp.dist[prev_customer, current_customer] / speed
            total_time = cumulative_time + prev_service_time + displacement_time
            ready_time = self.prp.customers[current_customer]['ready_time']
            if total_time < ready_time:
                total_time = ready_time
            cumulative_time = total_time

            if is_separator:
                objective += DRIVER_COST * cumulative_time
                cumulative_time = 0
                cumulative_payload = 0
                prev_customer = 0
                route_index += 1
            else:
                objective += const3 * dist * (total_payloads[route_index] - cumulative_payload)
                cumulative_payload += self.prp.customers[current_customer]['demand']
                prev_customer = current_customer

        return objective

    def split_route(self, chromosome):
        """
        Given a chromosome, compute the routes according to constraints of payload and time.
        :param chromosome: a chromosome without separator
        :return: a list of routes
        """
        not_visited = copy.deepcopy(chromosome)
        routes = []
        max_payload = self.prp.max_payload
        while len(not_visited) > 0:
            not_visited_aux = copy.deepcopy(not_visited)
            current_route = []
            current_payload = 0
            current_time = 0
            prev_customer = 0
            for item in not_visited_aux:
                current_customer = item[0]
                speed = item[1]

                prev_service_time = self.prp.customers[prev_customer]['service_time']
                displacement_time = self.prp.dist[prev_customer, current_customer] / speed
                total_time = current_time + prev_service_time + displacement_time

                ready_time = self.prp.customers[current_customer]['ready_time']
                due_time = self.prp.customers[current_customer]['due_time']
                if total_time < ready_time:
                    total_time = ready_time

                if (current_payload + self.prp.customers[current_customer]['demand'] <= max_payload) and \
                        (ready_time <= total_time <= due_time):
                    current_payload += self.prp.customers[current_customer]['demand']
                    current_time = total_time
                    not_visited.remove(item)
                    current_route.append(item)  # item is a pair [customer, speed]
                    prev_customer = current_customer
            routes.append(current_route)
        return routes

    
    def shift(self, chromosome, mutation_rate, speed_mutation_rate):
       
        _chromosome = copy.deepcopy(chromosome)
        # remove separators
        _chromosome = [x for x in _chromosome if x[0] != SEPARATOR]

        n = len(chromosome)
        for i in range(n):
            if random.random() < speed_mutation_rate:
                _chromosome[i][1] = random.randint(self.prp.min_speed, self.prp.max_speed)

            if random.random() < mutation_rate:
                start = randrange(0, n)
                end = randrange(start, n)

                chromosome_mid = chromosome[start:end]
                #chromosome_mid.reverse()
                _chromosome = chromosome[0:start] + chromosome[end:] + chromosome_mid
        return _chromosome


    def add_separator(self, chromosome):
        chromosome = copy.deepcopy(chromosome)
        # TODO: Caso ocorrer uma mutação, atribuimos valores aleatórios para a velocidade do separador
        routes = self.split_route(chromosome)
        chromosome = []
        for route in routes:
            speed_sep = random.randint(self.prp.min_speed, self.prp.max_speed)
            chromosome += route + [[SEPARATOR, speed_sep]]
        return chromosome

    def crossover(self, parent1, parent2):
        """
        OX crossover: ``Given two parents, two random crossover points are selected partitioning them into a left, middle
        and right portion. The ordered two-point crossover behaves in the following way: child1 inherits its left and
        right section from parent1, and its middle section is determined´´.
        (Accessed from https://www.researchgate.net/publication/331580514_Immune_Based_Genetic_Algorithm_to_Solve_a_Combinatorial_Optimization_Problem_Application_to_Traveling_Salesman_Problem_Volume_5_Advanced_Intelligent_Systems_for_Computing_Sciences)

        Ex.
        Parent1: [9,2,7,|5,4,3,|6,1,8]      Parent1: [9,2,7,|5,4,3,|6,1,8]
        Child1:  [2,8,6,|5,4,3,|9,7,1]      Child2:  [2,7,4,|6,9,5,|3,1,8]
        Parent2: [2,8,3,|6,9,5,|7,4,1]      Parent2: [2,8,3,|6,9,5,|7,4,1]

        After OX Crossover, we select randomly positions to separators

        :param parent1: array representing a route
        :param parent2: array representing a route
        :return: the newly generated children
        """
        route_size = len(parent1)
        parent1_aux = copy.deepcopy(parent1)
        parent2_aux = copy.deepcopy(parent2)

        n = len(parent1)
        index1 = randrange(0, n)
        index2 = randrange(index1, n)

        child1 = [0] * route_size
        child2 = [0] * route_size

        for i in range(index1, index2):
            child1[i] = parent1[i]
            child2[i] = parent2[i]
            for j in range(0, len(parent1_aux)):
                if parent1_aux[j][0] == parent2[i][0]:
                    parent1_aux.remove(parent1_aux[j])
                    break
            for j in range(0, len(parent2_aux)):
                if parent2_aux[j][0] == parent1[i][0]:
                    parent2_aux.remove(parent2_aux[j])
                    break

        for i in range(0, len(parent1_aux)):
            if i < index1:
                child1[i] = parent2_aux[i]
                child2[i] = parent1_aux[i]
                self.change_speed(child1[i], child2[i])
            else:
                child1[i + index2 - index1] = parent2_aux[i]
                child2[i + index2 - index1] = parent1_aux[i]
                self.change_speed(child1[i + index2 - index1], child2[i + index2 - index1])

        return child1, child2

    def change_speed(self, gene1, gene2):
        """
        Given two genes, change their speeds with probability 0.5
        :param gene1:
        :param gene2:
        :return:
        """
        if random.random() < 0.5:
            aux = gene1[1]
            gene1[1] = gene2[1]
            gene2[1] = aux

    def compute_total_payload(self, chromosome):
        """
        Given a chromosome, compute the total payload of each route
        :param chromosome: a chromosome
        :return: a list with the total payload of each route
        """
        total_payloads = []
        current_payload = 0
        for item in chromosome:
            customer = item[0]
            if customer == SEPARATOR:
                total_payloads.append(current_payload)
                current_payload = 0
            else:
                current_payload += self.prp.customers[customer]['demand']

        return total_payloads


def genetic_algorithm_solver(prp, population_size, ngen,
                             crossover_rate_decay,
                             mutation_rate_decay,
                             speed_mutation_rate,
                             selection_method,
                             min_route_mutation_rate=0.0,
                             route_mutation_rate=1.0,
                             time_limit=1800,
                             maintain_diversity=False,
                             elitism_rate=0.0,
                             patience=200):
    population = prp.generate_initial_population(population_size)

    start = time.time()
    fitness_scores = []
    crossover_rate = 1
    non_improvement = 0
    prev_fitness = -1
    for n in range(0, ngen):
        best_chromosome = min(population, key=prp.fitness)
        fitness_score = prp.fitness(best_chromosome)
        fitness_scores.append(fitness_score)
        print("Generation", n, "Best Fitness", fitness_score)
        print("Crossover Rate", crossover_rate, "Mutation Rate", route_mutation_rate)
        population = prp.generate_next_population(current_population=population,
                                                  crossover_rate=crossover_rate,
                                                  route_mutation_rate=route_mutation_rate,
                                                  speed_mutation_rate=speed_mutation_rate,
                                                  elitism_rate=elitism_rate,
                                                  maintain_diversity=maintain_diversity,
                                                  selection_method=selection_method)

        if route_mutation_rate > min_route_mutation_rate:
            route_mutation_rate -= mutation_rate_decay

        crossover_rate *= crossover_rate_decay

        # Time Limit
        end = time.time()
        if (end - start) >= time_limit:
            print("Time Limit", time_limit)
            break

        if (prev_fitness - fitness_score) < 0.1:
            non_improvement += 1
        else:
            non_improvement = 0

        if non_improvement == patience:
            print("Non improvement", non_improvement)
            break
        prev_fitness = fitness_score

    return fitness_scores, best_chromosome


def plot_metrics(scores, filepath=None):
    formatted_dict = {'Generations': [],
                      'Fitness Scores': [], }

    for i, score in enumerate(scores):
        formatted_dict['Generations'].append(i)
        formatted_dict['Fitness Scores'].append(score)

    df_metrics = pd.DataFrame(formatted_dict)
    sns.lineplot(data=df_metrics, x='Generations', y='Fitness Scores')
    if filepath is None:
        plt.show()
    else:
        plt.savefig(filepath)

# %%
import random
import time
import pandas as pd


if __name__ == '__main__':
    random.seed(42)


    for instance_size in [100]:
        # for ref_cost in [578.7815538, 643.0906153]:
        for ref_cost in [2175.292804, 2619.790834]:
            results = {'time': [], 'result': [], 'fleet size': []}
            for i in range(1, 150):
                instance_name = "UK{}_01".format(instance_size)
                #config T7
                instance = read_instance(inst_name=instance_name)
                prp = PRP_Genetic(instance)
                ngen = 1000
                final_mutation_rate = 1 / instance_size
                mutation_rate_decay = (1 - final_mutation_rate) / ngen
                start = time.time()
                fitness_scores, best_chromosome = genetic_algorithm_solver(prp,
                                                                           population_size=100,
                                                                           ngen=ngen,
                                                                           crossover_rate_decay=1,
                                                                           mutation_rate_decay=mutation_rate_decay,
                                                                           route_mutation_rate=1,
                                                                           min_route_mutation_rate=1 / instance_size,
                                                                           speed_mutation_rate=1 / instance_size,
                                                                           elitism_rate=0.15,
                                                                           maintain_diversity=False,
                                                                           selection_method=prp.tournament_selection,
                                                                           patience=1000,
                                                                           time_limit=300,
                                                                           #ref_cost=ref_cost
                                                                           )

                n_routes = sum([1 for item in best_chromosome if item[0] == -1])
                print(best_chromosome)
                plot_metrics(fitness_scores)

                end = time.time()
                min_fit = min(fitness_scores)

                results['result'].append(min_fit)
                #results['time'].append(target_time)
                results['fleet size'].append(n_routes)

            df = pd.DataFrame(results)
            df.to_csv('ttplots_uk_{}_configB_{}.csv'.format(instance_size, ref_cost))
# Out:
# Generation 0 Best Fitness 5704.8528517509885
# Crossover Rate 1 Mutation Rate 1
# Generation 1 Best Fitness 5704.8528517509885
# Crossover Rate 1 Mutation Rate 0.99901
# Generation 2 Best Fitness 5572.713046108565
# Crossover Rate 1 Mutation Rate 0.9980199999999999
# Generation 3 Best Fitness 5339.788533697383
# Crossover Rate 1 Mutation Rate 0.9970299999999999
# Generation 4 Best Fitness 5265.813965175317
# Crossover Rate 1 Mutation Rate 0.9960399999999998
# Generation 5 Best Fitness 5132.943126314318
# Crossover Rate 1 Mutation Rate 0.9950499999999998
# Generation 6 Best Fitness 5019.35426569646
# Crossover Rate 1 Mutation Rate 0.9940599999999997
# Generation 7 Best Fitness 4876.093544643662
# Crossover Rate 1 Mutation Rate 0.9930699999999997
# Generation 8 Best Fitness 4840.288282695529
# Crossover Rate 1 Mutation Rate 0.9920799999999996
# Generation 9 Best Fitness 4537.9110662015
# Crossover Rate 1 Mutation Rate 0.9910899999999996
# Generation 10 Best Fitness 4537.9110662015
# Crossover Rate 1 Mutation Rate 0.9900999999999995
# Generation 11 Best Fitness 4537.9110662015
# Crossover Rate 1 Mutation Rate 0.9891099999999995
# Generation 12 Best Fitness 4370.414465213956
# Crossover Rate 1 Mutation Rate 0.9881199999999994
# Generation 13 Best Fitness 4370.414465213956
# Crossover Rate 1 Mutation Rate 0.9871299999999994
# Generation 14 Best Fitness 4117.349660335747
# Crossover Rate 1 Mutation Rate 0.9861399999999994
# Generation 15 Best Fitness 4117.349660335747
# Crossover Rate 1 Mutation Rate 0.9851499999999993
# Generation 16 Best Fitness 4116.741082099356
# Crossover Rate 1 Mutation Rate 0.9841599999999993
# Generation 17 Best Fitness 4116.741082099356
# Crossover Rate 1 Mutation Rate 0.9831699999999992
# Generation 18 Best Fitness 4116.741082099356
# Crossover Rate 1 Mutation Rate 0.9821799999999992
# Generation 19 Best Fitness 4020.9306125562703
# Crossover Rate 1 Mutation Rate 0.9811899999999991
# Generation 20 Best Fitness 4020.9306125562703
# Crossover Rate 1 Mutation Rate 0.9801999999999991
# Generation 21 Best Fitness 3895.4408220826635
# Crossover Rate 1 Mutation Rate 0.979209999999999
# Generation 22 Best Fitness 3895.4408220826635
# Crossover Rate 1 Mutation Rate 0.978219999999999
# Generation 23 Best Fitness 3888.727774630818
# Crossover Rate 1 Mutation Rate 0.9772299999999989
# Generation 24 Best Fitness 3888.727774630818
# Crossover Rate 1 Mutation Rate 0.9762399999999989
# Generation 25 Best Fitness 3871.104753567324
# Crossover Rate 1 Mutation Rate 0.9752499999999988
# Generation 26 Best Fitness 3677.173302064872
# Crossover Rate 1 Mutation Rate 0.9742599999999988
# Generation 27 Best Fitness 3540.4693114811816
# Crossover Rate 1 Mutation Rate 0.9732699999999987
# Generation 28 Best Fitness 3497.9765168822873
# Crossover Rate 1 Mutation Rate 0.9722799999999987
# Generation 29 Best Fitness 3497.9765168822873
# Crossover Rate 1 Mutation Rate 0.9712899999999987
# Generation 30 Best Fitness 3497.9765168822873
# Crossover Rate 1 Mutation Rate 0.9702999999999986
# Generation 31 Best Fitness 3497.9765168822873
# Crossover Rate 1 Mutation Rate 0.9693099999999986
# Generation 32 Best Fitness 3497.9765168822873
# Crossover Rate 1 Mutation Rate 0.9683199999999985
# Generation 33 Best Fitness 3497.9765168822873
# Crossover Rate 1 Mutation Rate 0.9673299999999985
# Generation 34 Best Fitness 3416.5087310073195
# Crossover Rate 1 Mutation Rate 0.9663399999999984
# Generation 35 Best Fitness 3416.5087310073195
# Crossover Rate 1 Mutation Rate 0.9653499999999984
# Generation 36 Best Fitness 3416.5087310073195
# Crossover Rate 1 Mutation Rate 0.9643599999999983
# Generation 37 Best Fitness 3416.5087310073195
# Crossover Rate 1 Mutation Rate 0.9633699999999983
# Generation 38 Best Fitness 3366.434252352347
# Crossover Rate 1 Mutation Rate 0.9623799999999982
# Generation 39 Best Fitness 3366.434252352347
# Crossover Rate 1 Mutation Rate 0.9613899999999982
# Generation 40 Best Fitness 3261.7857180581364
# Crossover Rate 1 Mutation Rate 0.9603999999999981
# Generation 41 Best Fitness 3261.7857180581364
# Crossover Rate 1 Mutation Rate 0.9594099999999981
# Generation 42 Best Fitness 3261.7857180581364
# Crossover Rate 1 Mutation Rate 0.958419999999998
# Generation 43 Best Fitness 3261.7857180581364
# Crossover Rate 1 Mutation Rate 0.957429999999998
# Generation 44 Best Fitness 3261.7857180581364
# Crossover Rate 1 Mutation Rate 0.956439999999998
# Generation 45 Best Fitness 3229.359175696356
# Crossover Rate 1 Mutation Rate 0.9554499999999979
# Generation 46 Best Fitness 3229.359175696356
# Crossover Rate 1 Mutation Rate 0.9544599999999979
# Generation 47 Best Fitness 3229.359175696356
# Crossover Rate 1 Mutation Rate 0.9534699999999978
# Generation 48 Best Fitness 3229.359175696356
# Crossover Rate 1 Mutation Rate 0.9524799999999978
# Generation 49 Best Fitness 3186.738374761967
# Crossover Rate 1 Mutation Rate 0.9514899999999977
# Generation 50 Best Fitness 3186.738374761967
# Crossover Rate 1 Mutation Rate 0.9504999999999977
# Generation 51 Best Fitness 3186.738374761967
# Crossover Rate 1 Mutation Rate 0.9495099999999976
# Generation 52 Best Fitness 3186.738374761967
# Crossover Rate 1 Mutation Rate 0.9485199999999976
# Generation 53 Best Fitness 3149.50108457674
# Crossover Rate 1 Mutation Rate 0.9475299999999975
# Generation 54 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9465399999999975
# Generation 55 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9455499999999974
# Generation 56 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9445599999999974
# Generation 57 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9435699999999974
# Generation 58 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9425799999999973
# Generation 59 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9415899999999973
# Generation 60 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9405999999999972
# Generation 61 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9396099999999972
# Generation 62 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9386199999999971
# Generation 63 Best Fitness 3005.1991093404154
# Crossover Rate 1 Mutation Rate 0.9376299999999971
# Generation 64 Best Fitness 2887.657648018
# Crossover Rate 1 Mutation Rate 0.936639999999997
# Generation 65 Best Fitness 2887.657648018
# Crossover Rate 1 Mutation Rate 0.935649999999997
# Generation 66 Best Fitness 2887.657648018
# Crossover Rate 1 Mutation Rate 0.9346599999999969
# Generation 67 Best Fitness 2887.657648018
# Crossover Rate 1 Mutation Rate 0.9336699999999969
# Generation 68 Best Fitness 2887.657648018
# Crossover Rate 1 Mutation Rate 0.9326799999999968
# Generation 69 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9316899999999968
# Generation 70 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9306999999999968
# Generation 71 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9297099999999967
# Generation 72 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9287199999999967
# Generation 73 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9277299999999966
# Generation 74 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9267399999999966
# Generation 75 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9257499999999965
# Generation 76 Best Fitness 2809.8782467815163
# Crossover Rate 1 Mutation Rate 0.9247599999999965
# Generation 77 Best Fitness 2809.252094286217
# Crossover Rate 1 Mutation Rate 0.9237699999999964
# Generation 78 Best Fitness 2809.252094286217
# Crossover Rate 1 Mutation Rate 0.9227799999999964
# Generation 79 Best Fitness 2809.252094286217
# Crossover Rate 1 Mutation Rate 0.9217899999999963
# Generation 80 Best Fitness 2800.2069349775707
# Crossover Rate 1 Mutation Rate 0.9207999999999963
# Generation 81 Best Fitness 2747.5649013951697
# Crossover Rate 1 Mutation Rate 0.9198099999999962
# Generation 82 Best Fitness 2747.5649013951697
# Crossover Rate 1 Mutation Rate 0.9188199999999962
# Generation 83 Best Fitness 2747.5649013951697
# Crossover Rate 1 Mutation Rate 0.9178299999999961
# Generation 84 Best Fitness 2747.5649013951697
# Crossover Rate 1 Mutation Rate 0.9168399999999961
# Generation 85 Best Fitness 2742.1579995317247
# Crossover Rate 1 Mutation Rate 0.9158499999999961
# Generation 86 Best Fitness 2742.1579995317247
# Crossover Rate 1 Mutation Rate 0.914859999999996
# Generation 87 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.913869999999996
# Generation 88 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9128799999999959
# Generation 89 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9118899999999959
# Generation 90 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9108999999999958
# Generation 91 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9099099999999958
# Generation 92 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9089199999999957
# Generation 93 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9079299999999957
# Generation 94 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9069399999999956
# Generation 95 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9059499999999956
# Generation 96 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9049599999999955
# Generation 97 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9039699999999955
# Generation 98 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9029799999999955
# Generation 99 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9019899999999954
# Generation 100 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9009999999999954
# Generation 101 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.9000099999999953
# Generation 102 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8990199999999953
# Generation 103 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8980299999999952
# Generation 104 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8970399999999952
# Generation 105 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8960499999999951
# Generation 106 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8950599999999951
# Generation 107 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.894069999999995
# Generation 108 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.893079999999995
# Generation 109 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8920899999999949
# Generation 110 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8910999999999949
# Generation 111 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8901099999999948
# Generation 112 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8891199999999948
# Generation 113 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8881299999999948
# Generation 114 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8871399999999947
# Generation 115 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8861499999999947
# Generation 116 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8851599999999946
# Generation 117 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8841699999999946
# Generation 118 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8831799999999945
# Generation 119 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8821899999999945
# Generation 120 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8811999999999944
# Generation 121 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8802099999999944
# Generation 122 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8792199999999943
# Generation 123 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8782299999999943
# Generation 124 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8772399999999942
# Generation 125 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8762499999999942
# Generation 126 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8752599999999942
# Generation 127 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8742699999999941
# Generation 128 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.8732799999999941
# Generation 129 Best Fitness 2698.1742437055095
# Crossover Rate 1 Mutation Rate 0.872289999999994
# Generation 130 Best Fitness 2680.1289098808916
# Crossover Rate 1 Mutation Rate 0.871299999999994
# Generation 131 Best Fitness 2680.1289098808916
# Crossover Rate 1 Mutation Rate 0.8703099999999939
# Generation 132 Best Fitness 2680.1289098808916
# Crossover Rate 1 Mutation Rate 0.8693199999999939
# Generation 133 Best Fitness 2680.1289098808916
# Crossover Rate 1 Mutation Rate 0.8683299999999938
# Generation 134 Best Fitness 2680.1289098808916
# Crossover Rate 1 Mutation Rate 0.8673399999999938
# Generation 135 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8663499999999937
# Generation 136 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8653599999999937
# Generation 137 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8643699999999936
# Generation 138 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8633799999999936
# Generation 139 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8623899999999936
# Generation 140 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8613999999999935
# Generation 141 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8604099999999935
# Generation 142 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8594199999999934
# Generation 143 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8584299999999934
# Generation 144 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8574399999999933
# Generation 145 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8564499999999933
# Generation 146 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8554599999999932
# Generation 147 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8544699999999932
# Generation 148 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8534799999999931
# Generation 149 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8524899999999931
# Generation 150 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.851499999999993
# Generation 151 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.850509999999993
# Generation 152 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.849519999999993
# Generation 153 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8485299999999929
# Generation 154 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8475399999999929
# Generation 155 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8465499999999928
# Generation 156 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8455599999999928
# Generation 157 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8445699999999927
# Generation 158 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8435799999999927
# Generation 159 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8425899999999926
# Generation 160 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8415999999999926
# Generation 161 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8406099999999925
# Generation 162 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8396199999999925
# Generation 163 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8386299999999924
# Generation 164 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8376399999999924
# Generation 165 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8366499999999923
# Generation 166 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8356599999999923
# Generation 167 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8346699999999923
# Generation 168 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8336799999999922
# Generation 169 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8326899999999922
# Generation 170 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8316999999999921
# Generation 171 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8307099999999921
# Generation 172 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.829719999999992
# Generation 173 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.828729999999992
# Generation 174 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8277399999999919
# Generation 175 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8267499999999919
# Generation 176 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8257599999999918
# Generation 177 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8247699999999918
# Generation 178 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8237799999999917
# Generation 179 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8227899999999917
# Generation 180 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8217999999999916
# Generation 181 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8208099999999916
# Generation 182 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8198199999999916
# Generation 183 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8188299999999915
# Generation 184 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8178399999999915
# Generation 185 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8168499999999914
# Generation 186 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8158599999999914
# Generation 187 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8148699999999913
# Generation 188 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8138799999999913
# Generation 189 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8128899999999912
# Generation 190 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8118999999999912
# Generation 191 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8109099999999911
# Generation 192 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8099199999999911
# Generation 193 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.808929999999991
# Generation 194 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.807939999999991
# Generation 195 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.806949999999991
# Generation 196 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8059599999999909
# Generation 197 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8049699999999909
# Generation 198 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8039799999999908
# Generation 199 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8029899999999908
# Generation 200 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8019999999999907
# Generation 201 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8010099999999907
# Generation 202 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.8000199999999906
# Generation 203 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7990299999999906
# Generation 204 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7980399999999905
# Generation 205 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7970499999999905
# Generation 206 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7960599999999904
# Generation 207 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7950699999999904
# Generation 208 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7940799999999903
# Generation 209 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7930899999999903
# Generation 210 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7920999999999903
# Generation 211 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7911099999999902
# Generation 212 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7901199999999902
# Generation 213 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7891299999999901
# Generation 214 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7881399999999901
# Generation 215 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.78714999999999
# Generation 216 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.78615999999999
# Generation 217 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7851699999999899
# Generation 218 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7841799999999899
# Generation 219 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7831899999999898
# Generation 220 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7821999999999898
# Generation 221 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7812099999999897
# Generation 222 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7802199999999897
# Generation 223 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7792299999999897
# Generation 224 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7782399999999896
# Generation 225 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7772499999999896
# Generation 226 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7762599999999895
# Generation 227 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7752699999999895
# Generation 228 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7742799999999894
# Generation 229 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7732899999999894
# Generation 230 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7722999999999893
# Generation 231 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7713099999999893
# Generation 232 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7703199999999892
# Generation 233 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7693299999999892
# Generation 234 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7683399999999891
# Generation 235 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7673499999999891
# Generation 236 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.766359999999989
# Generation 237 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.765369999999989
# Generation 238 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.764379999999989
# Generation 239 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7633899999999889
# Generation 240 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7623999999999889
# Generation 241 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7614099999999888
# Generation 242 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7604199999999888
# Generation 243 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7594299999999887
# Generation 244 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7584399999999887
# Generation 245 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7574499999999886
# Generation 246 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7564599999999886
# Generation 247 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7554699999999885
# Generation 248 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7544799999999885
# Generation 249 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7534899999999884
# Generation 250 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7524999999999884
# Generation 251 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7515099999999884
# Generation 252 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7505199999999883
# Generation 253 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7495299999999883
# Generation 254 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7485399999999882
# Generation 255 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7475499999999882
# Generation 256 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7465599999999881
# Generation 257 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7455699999999881
# Generation 258 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.744579999999988
# Generation 259 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.743589999999988
# Generation 260 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7425999999999879
# Generation 261 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7416099999999879
# Generation 262 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7406199999999878
# Generation 263 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7396299999999878
# Generation 264 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7386399999999878
# Generation 265 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7376499999999877
# Generation 266 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7366599999999877
# Generation 267 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7356699999999876
# Generation 268 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7346799999999876
# Generation 269 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7336899999999875
# Generation 270 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7326999999999875
# Generation 271 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7317099999999874
# Generation 272 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7307199999999874
# Generation 273 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7297299999999873
# Generation 274 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7287399999999873
# Generation 275 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7277499999999872
# Generation 276 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7267599999999872
# Generation 277 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7257699999999871
# Generation 278 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7247799999999871
# Generation 279 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.723789999999987
# Generation 280 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.722799999999987
# Generation 281 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.721809999999987
# Generation 282 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7208199999999869
# Generation 283 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7198299999999869
# Generation 284 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7188399999999868
# Generation 285 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7178499999999868
# Generation 286 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7168599999999867
# Generation 287 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7158699999999867
# Generation 288 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7148799999999866
# Generation 289 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7138899999999866
# Generation 290 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7128999999999865
# Generation 291 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7119099999999865
# Generation 292 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7109199999999865
# Generation 293 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7099299999999864
# Generation 294 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7089399999999864
# Generation 295 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7079499999999863
# Generation 296 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7069599999999863
# Generation 297 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7059699999999862
# Generation 298 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7049799999999862
# Generation 299 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7039899999999861
# Generation 300 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7029999999999861
# Generation 301 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.702009999999986
# Generation 302 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.701019999999986
# Generation 303 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.7000299999999859
# Generation 304 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6990399999999859
# Generation 305 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6980499999999858
# Generation 306 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6970599999999858
# Generation 307 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6960699999999858
# Generation 308 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6950799999999857
# Generation 309 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6940899999999857
# Generation 310 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6930999999999856
# Generation 311 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6921099999999856
# Generation 312 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6911199999999855
# Generation 313 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6901299999999855
# Generation 314 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6891399999999854
# Generation 315 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6881499999999854
# Generation 316 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6871599999999853
# Generation 317 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6861699999999853
# Generation 318 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6851799999999852
# Generation 319 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6841899999999852
# Generation 320 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6831999999999852
# Generation 321 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6822099999999851
# Generation 322 Best Fitness 2609.4874161580688
# Crossover Rate 1 Mutation Rate 0.6812199999999851

# %%
"""
this model is based on paper "An adaptive large neighborhood search heuristic for the
Pollution-Routing Problem", Emrah Demir, Tolga Bektas, Gilbert Laporte
"""
"""import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import random
import math

K = 10**9
L = 10**9

def compute_objective(instance:PRProblem, x_vars, z_vars, f_vars, s_vars):
    const1 = FRICTION_FACTOR * ENGINE_SPEED * ENGINE_DISPLACEMENT * LAMBDA
    const2 = CURB_WEIGHT * GAMMA * LAMBDA
    const3 = GAMMA * LAMBDA
    const4 = BETTA * GAMMA * LAMBDA
    alphas = genarateRandomAlphaMatrix()

    objective = 0
    for i in range(0, len(instance.customers)):
        for j in range(0, len(instance.customers)):
            if i != j:
                sum_z = 0
                sum_z2 = 0
                for r in range(instance.min_speed, instance.max_speed + 1):
                    sum_z += z_vars[(i, j, r)] / r
                    sum_z2 += z_vars[(i, j, r)] * (r ** 2)
                objective += const1 * instance.dist[(i, j)] * sum_z
                objective += const2 * ALPHA * instance.dist[(i, j)] * x_vars[(i, j)]
                objective += const3 * ALPHA * instance.dist[(i, j)] * f_vars[(i, j)]
                objective += const4 * instance.dist[(i, j)] * sum_z2
        if i > 0:
            objective += DRIVER_COST * s_vars[i]
    return objective


def constraint_12(model, instance:PRProblem, x_vars):
    _sum = 0
    for j in range(1, len(instance.customers)):
        _sum += x_vars[(0, j)]
    
    constraint_12_name = "constraint_12"
    model.addConstr(_sum == instance.fleet_size, constraint_12_name)


def constraint_13(model, instance:PRProblem, x_vars):
    for i in range(1, len(instance.customers)):
        _sum = 0
        for j in range(0, len(instance.customers)):
            if i != j:
                _sum += x_vars[(i, j)]
        
        constraint_13_name = "constraint_13_{}".format(i)
        model.addConstr(_sum == 1, constraint_13_name)


def constraint_14(model, instance: PRProblem, x_vars):
    for j in range(1, len(instance.customers)):
        _sum = 0
        for i in range(0, len(instance.customers)):
            if i != j:
                _sum += x_vars[(i, j)]

        constraint_14_name = "constraint_14_{}".format(j)
        model.addConstr(_sum == 1, constraint_14_name)


def constraint_15(model, instance:PRProblem, f_vars):
    for i in range(1, len(instance.customers)):
        q = instance.customers[i]["demand"]
        _sum1 = 0
        _sum2 = 0
        for j in range(0, len(instance.customers)):
            if i != j:
                _sum1 += f_vars[(j, i)]
                _sum2 += f_vars[(i, j)]

        constraint_15_name = "constraint_15_{}".format(i)
        model.addConstr(_sum1 - _sum2 == q, constraint_15_name)


def constraint_16(model, instance: PRProblem,  x_vars, f_vars):
    Q = instance.max_payload
    for i in range(0, len(instance.customers)):
        q_i = instance.customers[i]["demand"]
        for j in range(0, len(instance.customers)):
            q_j = instance.customers[j]["demand"]
            if i != j:
                constraint_16_1 = "constraint_16_1_{}_{}".format(i, j)
                constraint_16_2 = "constraint_16_2_{}_{}".format(i, j)
                model.addConstr(q_j * x_vars[(i, j)] <= f_vars[(i, j)], constraint_16_1)
                model.addConstr(f_vars[(i, j)] <= (Q - q_i) * x_vars[(i, j)], constraint_16_2)


def constraint_17(model, instance: PRProblem,  y_vars, z_vars, x_vars):
    for i in range(0, len(instance.customers)):
        t_i = instance.customers[i]["service_time"]
        for j in range(1, len(instance.customers)):
            _sum = 0
            if i != j:
                if i > 0:
                    _sum = y_vars[i] - y_vars[j] + t_i
                else:
                    _sum = - y_vars[j] + t_i

                for r in range(instance.min_speed, instance.max_speed + 1):
                    _sum += instance.dist[(i, j)] * z_vars[(i, j, r)] / r   

                constraint_17_name = "constraint_17_{}_{}".format(i, j)
                model.addConstr(_sum <= K * (1 - x_vars[(i, j)]), constraint_17_name)

def constraint_17_indicator(model, instance: PRProblem,  y_vars, z_vars, x_vars):
    # reference: https://www.gurobi.com/documentation/8.0/refman/py_model_addgenconstrindic.html

    for i in range(0, len(instance.customers)):
        t_i = instance.customers[i]["service_time"]
        for j in range(1, len(instance.customers)):
            _sum = 0
            if i != j:
                if i > 0:
                    _sum = y_vars[i] + t_i
                else:
                    _sum = t_i
                for r in range(instance.min_speed, instance.max_speed + 1):
                    _sum += instance.dist[(i, j)] * z_vars[(i, j, r)] / r

                model.addGenConstrIndicator(x_vars[(i, j)], True, _sum <= y_vars[j])

def constraint_18(model, instance: PRProblem,  y_vars):
    for i in range(1, len(instance.customers)):
        a = instance.customers[i]["ready_time"]
        b = instance.customers[i]["due_time"]

        constraint_id_18_1 = "constraint_18_1_{}".format(i)
        constraint_id_18_2 = "constraint_18_2_{}".format(i)
        model.addConstr(a <= y_vars[i], constraint_id_18_1)
        model.addConstr(y_vars[i] <= b, constraint_id_18_2)


def constraint_19(model, instance: PRProblem,  x_vars, z_vars, y_vars, s_vars):
    for j in range(1, len(instance.customers)):
        t_j = instance.customers[j]["service_time"]
        _sum = y_vars[j] + t_j - s_vars[j]
        for r in range(instance.min_speed, instance.max_speed + 1):
            _sum += instance.dist[(j, 0)] * z_vars[(j, 0, r)] / r

        constraint_19_name = "constraint_19_{}".format(j)
        model.addConstr(_sum <= L * (1 - x_vars[(j, 0)]), constraint_19_name)


def constraint_19_indicator(model, instance: PRProblem,  x_vars, z_vars, y_vars, s_vars):
    for j in range(1, len(instance.customers)):
        t_j = instance.customers[j]["service_time"]
        _sum = y_vars[j] + t_j
        for r in range(instance.min_speed, instance.max_speed + 1):
            _sum += instance.dist[(j, 0)] * z_vars[(j, 0, r)] / r

        model.addGenConstrIndicator(x_vars[(j, 0)], True, _sum <= s_vars[j])


def constraint_20(model, instance:PRProblem, x_vars, z_vars):
    for i in range(0, len(instance.customers)):
        for j in range(0, len(instance.customers)):
            if i != j:
                _sum = 0
                for r in range(instance.min_speed, instance.max_speed + 1):
                    _sum += z_vars[(i, j, r)]

                constraint_20_name = "constraint_20_{}_{}".format(i, j)
                model.addConstr(_sum == x_vars[(i, j)], constraint_20_name)


def build_model(instance: PRProblem):
    model = gp.Model("PRP")

    z_vars = {}
    x_vars = {}
    f_vars = {}
    y_vars = {}
    s_vars = {}

    for i in range(0, len(instance.customers)):
        if i > 0:
            y_vars[i] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, name="y_{}".format(i))
            s_vars[i] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, name="s_{}".format(i))
        for j in range(0, len(instance.customers)):
            if i != j:
                x_vars[(i, j)] = model.addVar(vtype=GRB.BINARY, name="x_{}_{}".format(i, j))
                f_vars[(i, j)] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, name="f_{}_{}".format(i, j))
                for r in range(instance.min_speed, instance.max_speed + 1):
                    z_vars[(i, j, r)] = model.addVar(vtype=GRB.BINARY, name="z_{}_{}_{}".format(i, j, r))
    instance.fleet_size = model.addVar(vtype=GRB.INTEGER, lb=0, name="m")
    objective = compute_objective(instance, x_vars, z_vars, f_vars, s_vars)
    model.setObjective(objective, GRB.MINIMIZE)

    # adding constraints
    constraint_12(model, instance, x_vars)
    constraint_13(model, instance, x_vars)
    constraint_14(model, instance, x_vars)
    constraint_15(model, instance, f_vars)
    constraint_16(model, instance,  x_vars, f_vars)
    # constraint_17(model, instance,  y_vars, z_vars, x_vars)
    constraint_17_indicator(model, instance, y_vars, z_vars, x_vars)
    constraint_18(model, instance,  y_vars)
    # constraint_19(model, instance, x_vars, z_vars, y_vars, s_vars)
    constraint_19_indicator(model, instance, x_vars, z_vars, y_vars, s_vars)
    constraint_20(model, instance, x_vars, z_vars)

    return model, x_vars, z_vars

def genarateRandomAlphaMatrix():
    alphas = {}

    for i in range(0, len(instance.customers)):
        for j in range(0, len(instance.customers)):
            fixedDegree = 0.0107459922
            alphas[(i, j)] = GRAVITY * (math.sin(fixedDegree) + ROLLING_RESISTANCE * math.cos(fixedDegree))

    return alphas

def save_results_CSV(lower_bounds:list, upper_bounds:list, times:list, fleet_sizes:list, filepath):
    df = pd.DataFrame({'time':times, 'lower_bounds':lower_bounds, 'upper_bounds':upper_bounds, 'fleet size':fleet_sizes})
    df.to_csv(filepath)

if __name__ == '__main__':
    random.seed(42)
    lower_bounds = []
    upper_bounds = []
    times = []
    fleet_sizes = []
    for n in [100]:
        for i in range(1, 2):
            if i < 10:
                instance_name = "{}{}".format("UK{}_0".format(n), i)
            else:
                instance_name = "{}{}".format("UK{}_".format(n), i)
            print(instance_name)
            instance = read_instance(inst_name=instance_name)

            model, x_vars, z_vars = build_model(instance)
            model.setParam('TimeLimit', 1800)
            model.optimize()
            print('Final Objective: {}'.format(model.objVal))
            for v in model.getVars():
                if v.varName == "m":
                    print('Fleet size: %g' % (v.x))
                    fleet_sizes.append(v.x)

            print('Route')
            for edge, v in x_vars.items():
                if v.X > 0.9:
                    for r in range(instance.min_speed, instance.max_speed + 1):
                        if z_vars[(edge[0], edge[1], r)].X > 0.9:
                            print("{}: {}".format(v.varName, v.X), "velocidade:", r)

            lower_bounds.append(model.objBound)
            upper_bounds.append(model.objVal)
            times.append(model.runtime)"""

        # filepath = "./pl_{}_results.csv".format(n)
        # save_results_CSV(lower_bounds, upper_bounds, times, fleet_sizes, filepath)

# %%
"""import random
import time
import pandas as pd

def sus_A(elitism, k):
    results = {'time': [], 'result': [], 'fleet size': []}
    for i in range(1, 21):
        if i < 10:
            instance_name = "{}{}".format("UK{}_0".format(instance_size), i)
        else:
            instance_name = "{}{}".format("UK{}_".format(instance_size), i)

        instance = read_instance(inst_name=instance_name)
        prp = PRP_Genetic(instance)
        ngen = 100000
        start = time.time()
        fitness_scores, best_chromosome = genetic_algorithm_solver(prp,
                                                                   population_size=100,
                                                                   ngen=ngen,
                                                                   crossover_rate_decay=1,
                                                                   mutation_rate_decay=0,
                                                                   route_mutation_rate=1 / instance_size,
                                                                   min_route_mutation_rate=1 / instance_size,
                                                                   speed_mutation_rate=1 / instance_size,
                                                                   elitism_rate=elitism,
                                                                   maintain_diversity=False,
                                                                   selection_method=lambda pop, n: prp.sus(pop, n, k=k))
        n_routes = sum([1 for item in best_chromosome if item[0] == -1])
        print(best_chromosome)
        # plot_metrics(fitness_scores)

        end = time.time()
        min_fit = min(fitness_scores)

        results['result'].append(min_fit)
        results['time'].append((end - start))
        results['fleet size'].append(n_routes)

    return results

def sus_B(elitism, k):
    results = {'time': [], 'result': [], 'fleet size': []}
    for i in range(1, 21):
        if i < 10:
            instance_name = "{}{}".format("UK{}_0".format(instance_size), i)
        else:
            instance_name = "{}{}".format("UK{}_".format(instance_size), i)

        instance = read_instance(inst_name=instance_name)
        prp = PRP_Genetic(instance)
        ngen = 100000
        final_mutation_rate = 1 / instance_size
        mutation_rate_decay = (1 - final_mutation_rate) / ngen
        start = time.time()
        fitness_scores, best_chromosome = genetic_algorithm_solver(prp,
                                                                   population_size=100,
                                                                   ngen=ngen,
                                                                   crossover_rate_decay=1,
                                                                   mutation_rate_decay=mutation_rate_decay,
                                                                   route_mutation_rate=1,
                                                                   min_route_mutation_rate=1 / instance_size,
                                                                   speed_mutation_rate=1 / instance_size,
                                                                   elitism_rate=elitism,
                                                                   maintain_diversity=False,
                                                                   selection_method=lambda pop, n: prp.sus(pop, n, k=k))
        n_routes = sum([1 for item in best_chromosome if item[0] == -1])
        print(best_chromosome)
        # plot_metrics(fitness_scores)

        end = time.time()
        min_fit = min(fitness_scores)

        results['result'].append(min_fit)
        results['time'].append((end - start))
        results['fleet size'].append(n_routes)

    return results


def tournament_A(elitism):
    results = {'time': [], 'result': [], 'fleet size': []}
    for i in range(1, 21):
        if i < 10:
            instance_name = "{}{}".format("UK{}_0".format(instance_size), i)
        else:
            instance_name = "{}{}".format("UK{}_".format(instance_size), i)

        instance = read_instance(inst_name=instance_name)
        prp = PRP_Genetic(instance)
        ngen = 100000
        start = time.time()
        fitness_scores, best_chromosome = genetic_algorithm_solver(prp,
                                                                   population_size=100,
                                                                   ngen=ngen,
                                                                   crossover_rate_decay=1,
                                                                   mutation_rate_decay=0,
                                                                   route_mutation_rate=1 / instance_size,
                                                                   min_route_mutation_rate=1 / instance_size,
                                                                   speed_mutation_rate=1 / instance_size,
                                                                   elitism_rate=elitism,
                                                                   maintain_diversity=False,
                                                                   selection_method=prp.tournament_selection)
        n_routes = sum([1 for item in best_chromosome if item[0] == -1])
        print(best_chromosome)
        # plot_metrics(fitness_scores)

        end = time.time()
        min_fit = min(fitness_scores)

        results['result'].append(min_fit)
        results['time'].append((end - start))
        results['fleet size'].append(n_routes)

    return results


def tournament_B(elitism):
    results = {'time': [], 'result': [], 'fleet size': []}
    for i in range(1, 21):
        if i < 10:
            instance_name = "{}{}".format("UK{}_0".format(instance_size), i)
        else:
            instance_name = "{}{}".format("UK{}_".format(instance_size), i)

        instance = read_instance(inst_name=instance_name)
        prp = PRP_Genetic(instance)
        ngen = 100000
        final_mutation_rate = 1 / instance_size
        mutation_rate_decay = (1 - final_mutation_rate) / ngen
        start = time.time()
        fitness_scores, best_chromosome = genetic_algorithm_solver(prp,
                                                                   population_size=100,
                                                                   ngen=ngen,
                                                                   crossover_rate_decay=1,
                                                                   mutation_rate_decay=mutation_rate_decay,
                                                                   route_mutation_rate=1,
                                                                   min_route_mutation_rate=1 / instance_size,
                                                                   speed_mutation_rate=1 / instance_size,
                                                                   elitism_rate=elitism,
                                                                   maintain_diversity=False,
                                                                   selection_method=prp.tournament_selection)
        n_routes = sum([1 for item in best_chromosome if item[0] == -1])
        print(best_chromosome)

        end = time.time()
        min_fit = min(fitness_scores)

        results['result'].append(min_fit)
        results['time'].append((end - start))
        results['fleet size'].append(n_routes)

    return results


if __name__ == '__main__':
    random.seed(42)

    for elitism in [0.15]:
        for k in [5, 50]:
            for instance_size in [10, 20, 100, 200]:
                print("==================== Instance {}, elitism {}, k {}".format(instance_size, elitism, k))
                results = sus_A(elitism, k)
                df = pd.DataFrame(results)
                df.to_csv('ga_{}_config_A_{}_SUS_{}_results.csv'.format(instance_size, elitism, k))

                results = sus_B(elitism, k)
                df = pd.DataFrame(results)
                df.to_csv('ga_{}_config_B_{}_SUS_{}_results.csv'.format(instance_size, elitism, k))

"""
